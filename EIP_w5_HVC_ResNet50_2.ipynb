# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarchandan/EIP4/blob/master/EIP_w5_HVC_ResNet50_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/hvc_data.zip"
# !cp /content/gdrive/My\ Drive/hvc_encoded_3.csv /content/
# `hvc_encoded.csv` and `resized` should be available
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  hvc_encoded_3.csv  resized/  sample_data/

# %%
import pandas as pd

# %%
df = pd.read_csv('hvc_encoded_3.csv')
df.head()
# Out:
#       image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 0  resized/1.jpg              0  ...                        1              0
# 1  resized/2.jpg              1  ...                        1              0
# 2  resized/3.jpg              0  ...                        1              0
# 3  resized/4.jpg              0  ...                        1              0
# 4  resized/5.jpg              1  ...                        1              0
#
# [5 rows x 28 columns]

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(df, test_size=0.15)

# %%
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
# Columns for one-hot encoded labels
def get_columns_by_prefix(prefix):
  return [col for col in df if col.startswith(prefix)]

_gender_columns = get_columns_by_prefix('gender')
_qual_columns_ = get_columns_by_prefix('qual')
_age_columns_ = get_columns_by_prefix('age')
_weight_columns_ = get_columns_by_prefix('weight')
_bag_columns_ = get_columns_by_prefix('bag')
_footwear_columns_ = get_columns_by_prefix('footwear')
_emotion_columns_ = get_columns_by_prefix('emotion')
_bodypose_columns_ = get_columns_by_prefix('bodypose')

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %%
import keras
import numpy as np
import cv2
from keras.preprocessing.image import ImageDataGenerator
from __future__ import division

class DataGenerator(keras.utils.Sequence):
  
  def __init__(self, df, batch_size=32, shuffle=True, augmentation=None):
    self.df = df
    self.batch_size = batch_size
    self.shuffle = shuffle
    self.augmentation = augmentation

  def __len__(self):
    return int(np.ceil(self.df.shape[0] / self.batch_size))

  def __getitem__(self, index):
    """ return X=224,224,3,batch_size and y=num_classes,batch_size"""
    batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
    items = self.df.iloc[batch_slice]
    images = np.stack([cv2.imread(item['image_path']) for _, item in items.iterrows()])
    
    if self.augmentation is not None:
      images = self.augmentation.flow(images, shuffle=False, batch_size=self.batch_size).next()

    target = {
        'gender_output': items[_gender_columns].values,
        'imagequality_output': items[_qual_columns_].values,
        'age_output': items[_age_columns_].values,
        'weight_output': items[_weight_columns_].values,
        'bag_output': items[_bag_columns_].values,
        'footwear_output': items[_footwear_columns_].values,
        'emotion_output': items[_emotion_columns_].values,
        'bodypose_output': items[_bodypose_columns_].values
    }
    return images, target

  def on_epoch_end(self):
    """Shuffle data after each epoch"""
    if self.shuffle == True:
      self.df = self.df.sample(frac=1).reset_index(drop=True)
# Out:
# Using TensorFlow backend.

# %%
BATCH_SIZE=128
train_gen = DataGenerator(
    train_df,
    batch_size=BATCH_SIZE,
    shuffle=True,
    augmentation=ImageDataGenerator(horizontal_flip=True,
                                    vertical_flip=False,
                                    rotation_range=10,
                                    width_shift_range=0.3,
                                    height_shift_range=0.1,
                                    zoom_range=0.2)
  )
valid_gen = DataGenerator(val_df, batch_size=BATCH_SIZE, shuffle=False)

# %%
images, targets = next(iter(train_gen))

# %%
def get_unit_count(value_output):
  if (len(value_output.shape) > 1):
    return value_output.shape[1]
  else:
    return 1
num_units = { k.split("_output")[0]: get_unit_count(v) for k, v in targets.items() }
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'bodypose': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'imagequality': 3,
#  'weight': 4}

# %%
from keras import backend as K

class CyclicLR(keras.callbacks.Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
clr = CyclicLR(base_lr=0.0001, max_lr=.01, step_size=7220)

# %%
print(keras.__version__)
# Out:
# 2.2.5

# %%
from keras.models import Model, Sequential
from keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten,
    Dropout
)
from keras.layers import (
    Convolution2D,
    MaxPooling2D,
    AveragePooling2D,
    GlobalAveragePooling2D
)
from keras.layers import add
from keras.layers import BatchNormalization
from keras.regularizers import l2

from keras.applications.resnet_v2 import ResNet50V2

regularization_strength=0.0001

base_model = ResNet50V2(include_top=False)

neck = base_model.output
neck = GlobalAveragePooling2D()(neck)
neck = Dense(512, activation="relu")(neck)

def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(neck)
    neck = Dense(128, activation="relu")(neck)
    return neck

def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)
# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("imagequality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("bodypose", build_tower(neck))
model = Model(
    inputs=base_model.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, None, None, 6 256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, None, None, 6 0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 6 4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 6 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 6 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, None, None, 6 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, None, None, 6 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, None, None, 2 0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, None, None, 2 0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 6 16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 6 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 6 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, None, None, 6 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, None, None, 6 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, None, None, 2 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, None, None, 2 0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 6 16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 6 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 6 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, None, None, 6 0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 6 36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, None, None, 6 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, None, None, 6 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, None, None, 2 0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, None, None, 2 0           max_pooling2d_10[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, None, None, 2 1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, None, None, 2 0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, None, None, 1 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, None, None, 1 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, None, None, 5 131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, None, None, 5 0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, None, None, 5 0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, None, None, 1 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, None, None, 1 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, None, None, 5 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, None, None, 5 0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, None, None, 1 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, None, None, 1 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, None, None, 5 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, None, None, 5 0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, None, None, 1 0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 1 147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, None, None, 1 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, None, None, 1 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, None, None, 5 0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, None, None, 5 0           max_pooling2d_11[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, None, None, 5 2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, None, None, 5 0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 2 131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 2 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, None, None, 2 0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, None, None, 1 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, None, None, 1 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, None, None, 1 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 2 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, None, None, 2 0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, None, None, 1 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, None, None, 1 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 2 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, None, None, 2 0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, None, None, 1 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, None, None, 1 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 2 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, None, None, 2 0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, None, None, 1 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, None, None, 1 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 2 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, None, None, 2 0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, None, None, 1 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, None, None, 1 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 2 262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 2 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, None, None, 2 0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 2 589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, None, None, 2 0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, None, None, 1 0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, None, None, 1 0           max_pooling2d_12[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, None, None, 1 4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, None, None, 1 0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, None, None, 5 524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, None, None, 5 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, None, None, 5 0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, None, None, 2 2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, None, None, 2 0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, None, None, 2 8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, None, None, 2 0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, None, None, 5 1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, None, None, 5 0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, None, None, 5 0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, None, None, 2 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, None, None, 2 8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, None, None, 2 0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, None, None, 5 1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, None, None, 5 0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, None, None, 5 0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, None, None, 5 2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, None, None, 5 0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, None, None, 2 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, None, None, 2 8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, None, None, 2 0           post_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 2048)         0           post_relu[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 512)          1049088     global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 128)          65664       dropout_49[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 128)          65664       dropout_51[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 128)          65664       dropout_53[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 128)          65664       dropout_55[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 128)          65664       dropout_57[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 128)          65664       dropout_59[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 128)          65664       dropout_63[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 128)          65664       dropout_61[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 128)          0           dense_53[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 128)          0           dense_55[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 128)          0           dense_57[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 128)          0           dense_59[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 128)          0           dense_61[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 128)          0           dense_63[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 128)          0           dense_67[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 128)          0           dense_65[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 128)          16512       dropout_50[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 128)          16512       dropout_52[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 128)          16512       dropout_54[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 128)          16512       dropout_56[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 128)          16512       dropout_58[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 128)          16512       dropout_60[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 128)          16512       dropout_64[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 128)          16512       dropout_62[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_54[0][0]
# __________________________________________________________________________________________________
# imagequality_output (Dense)     (None, 3)            387         dense_56[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_58[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_60[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_62[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_64[0][0]
# __________________________________________________________________________________________________
# bodypose_output (Dense)         (None, 3)            387         dense_68[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            516         dense_66[0][0]
# ==================================================================================================
# Total params: 25,274,779
# Trainable params: 25,229,339
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
model.compile(
  optimizer='sgd',
  loss='categorical_crossentropy',
  metrics=['accuracy']
)

# %%
history = model.fit_generator(
  generator=train_gen,
  validation_data=valid_gen,
  epochs=20,
  callbacks=[clr]
)
# Out:
# Epoch 1/20
# 91/91 [==============================] - 125s 1s/step - loss: 9.6281 - gender_output_loss: 0.7357 - imagequality_output_loss: 1.1044 - age_output_loss: 1.5696 - weight_output_loss: 1.4146 - bag_output_loss: 0.9671 - footwear_output_loss: 1.1676 - bodypose_output_loss: 1.0429 - emotion_output_loss: 1.6262 - gender_output_acc: 0.4877 - imagequality_output_acc: 0.4092 - age_output_acc: 0.3507 - weight_output_acc: 0.2707 - bag_output_acc: 0.5453 - footwear_output_acc: 0.3687 - bodypose_output_acc: 0.5097 - emotion_output_acc: 0.0826 - val_loss: 9.1252 - val_gender_output_loss: 0.7194 - val_imagequality_output_loss: 1.0691 - val_age_output_loss: 1.5399 - val_weight_output_loss: 1.2932 - val_bag_output_loss: 0.9546 - val_footwear_output_loss: 1.1178 - val_bodypose_output_loss: 1.0093 - val_emotion_output_loss: 1.4219 - val_gender_output_acc: 0.4686 - val_imagequality_output_acc: 0.4504 - val_age_output_acc: 0.3738 - val_weight_output_acc: 0.4317 - val_bag_output_acc: 0.5673 - val_footwear_output_acc: 0.3905 - val_bodypose_output_acc: 0.5742 - val_emotion_output_acc: 0.0899
# Epoch 2/20
# 91/91 [==============================] - 118s 1s/step - loss: 9.0856 - gender_output_loss: 0.7186 - imagequality_output_loss: 1.0725 - age_output_loss: 1.5410 - weight_output_loss: 1.2717 - bag_output_loss: 0.9607 - footwear_output_loss: 1.1179 - bodypose_output_loss: 1.0216 - emotion_output_loss: 1.3815 - gender_output_acc: 0.5041 - imagequality_output_acc: 0.4427 - age_output_acc: 0.3632 - weight_output_acc: 0.4577 - bag_output_acc: 0.5432 - footwear_output_acc: 0.4001 - bodypose_output_acc: 0.5478 - emotion_output_acc: 0.2412 - val_loss: 8.6168 - val_gender_output_loss: 0.7073 - val_imagequality_output_loss: 1.0369 - val_age_output_loss: 1.5057 - val_weight_output_loss: 1.1460 - val_bag_output_loss: 0.9524 - val_footwear_output_loss: 1.0818 - val_bodypose_output_loss: 0.9858 - val_emotion_output_loss: 1.2009 - val_gender_output_acc: 0.5020 - val_imagequality_output_acc: 0.5044 - val_age_output_acc: 0.3915 - val_weight_output_acc: 0.6233 - val_bag_output_acc: 0.5643 - val_footwear_output_acc: 0.4219 - val_bodypose_output_acc: 0.5963 - val_emotion_output_acc: 0.5732
# Epoch 3/20
# 91/91 [==============================] - 120s 1s/step - loss: 8.6539 - gender_output_loss: 0.7164 - imagequality_output_loss: 1.0491 - age_output_loss: 1.5163 - weight_output_loss: 1.1450 - bag_output_loss: 0.9580 - footwear_output_loss: 1.0927 - bodypose_output_loss: 0.9959 - emotion_output_loss: 1.1805 - gender_output_acc: 0.5136 - imagequality_output_acc: 0.4859 - age_output_acc: 0.3751 - weight_output_acc: 0.5919 - bag_output_acc: 0.5360 - footwear_output_acc: 0.4143 - bodypose_output_acc: 0.5817 - emotion_output_acc: 0.5667 - val_loss: 8.2506 - val_gender_output_loss: 0.7014 - val_imagequality_output_loss: 1.0122 - val_age_output_loss: 1.4782 - val_weight_output_loss: 1.0487 - val_bag_output_loss: 0.9468 - val_footwear_output_loss: 1.0620 - val_bodypose_output_loss: 0.9623 - val_emotion_output_loss: 1.0390 - val_gender_output_acc: 0.5211 - val_imagequality_output_acc: 0.5319 - val_age_output_acc: 0.3949 - val_weight_output_acc: 0.6400 - val_bag_output_acc: 0.5580 - val_footwear_output_acc: 0.4430 - val_bodypose_output_acc: 0.6007 - val_emotion_output_acc: 0.7102
# Epoch 4/20
# 91/91 [==============================] - 119s 1s/step - loss: 8.3538 - gender_output_loss: 0.7013 - imagequality_output_loss: 1.0239 - age_output_loss: 1.4939 - weight_output_loss: 1.0754 - bag_output_loss: 0.9481 - footwear_output_loss: 1.0763 - bodypose_output_loss: 0.9784 - emotion_output_loss: 1.0566 - gender_output_acc: 0.5390 - imagequality_output_acc: 0.5114 - age_output_acc: 0.3794 - weight_output_acc: 0.6215 - bag_output_acc: 0.5355 - footwear_output_acc: 0.4199 - bodypose_output_acc: 0.5975 - emotion_output_acc: 0.6951 - val_loss: 8.0644 - val_gender_output_loss: 0.6905 - val_imagequality_output_loss: 1.0023 - val_age_output_loss: 1.4619 - val_weight_output_loss: 1.0089 - val_bag_output_loss: 0.9426 - val_footwear_output_loss: 1.0421 - val_bodypose_output_loss: 0.9503 - val_emotion_output_loss: 0.9659 - val_gender_output_acc: 0.5442 - val_imagequality_output_acc: 0.5442 - val_age_output_acc: 0.3915 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5540 - val_footwear_output_acc: 0.4632 - val_bodypose_output_acc: 0.6027 - val_emotion_output_acc: 0.7112
# Epoch 5/20
# 91/91 [==============================] - 119s 1s/step - loss: 8.2074 - gender_output_loss: 0.6978 - imagequality_output_loss: 1.0189 - age_output_loss: 1.4835 - weight_output_loss: 1.0428 - bag_output_loss: 0.9432 - footwear_output_loss: 1.0646 - bodypose_output_loss: 0.9666 - emotion_output_loss: 0.9900 - gender_output_acc: 0.5413 - imagequality_output_acc: 0.5168 - age_output_acc: 0.3792 - weight_output_acc: 0.6291 - bag_output_acc: 0.5414 - footwear_output_acc: 0.4350 - bodypose_output_acc: 0.6060 - emotion_output_acc: 0.7082 - val_loss: 7.9716 - val_gender_output_loss: 0.6841 - val_imagequality_output_loss: 0.9921 - val_age_output_loss: 1.4524 - val_weight_output_loss: 0.9963 - val_bag_output_loss: 0.9361 - val_footwear_output_loss: 1.0364 - val_bodypose_output_loss: 0.9402 - val_emotion_output_loss: 0.9339 - val_gender_output_acc: 0.5648 - val_imagequality_output_acc: 0.5506 - val_age_output_acc: 0.3910 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5594 - val_footwear_output_acc: 0.4735 - val_bodypose_output_acc: 0.6051 - val_emotion_output_acc: 0.7112
# Epoch 6/20
# 91/91 [==============================] - 119s 1s/step - loss: 8.1134 - gender_output_loss: 0.6940 - imagequality_output_loss: 1.0133 - age_output_loss: 1.4733 - weight_output_loss: 1.0300 - bag_output_loss: 0.9410 - footwear_output_loss: 1.0499 - bodypose_output_loss: 0.9452 - emotion_output_loss: 0.9666 - gender_output_acc: 0.5394 - imagequality_output_acc: 0.5255 - age_output_acc: 0.3811 - weight_output_acc: 0.6236 - bag_output_acc: 0.5413 - footwear_output_acc: 0.4510 - bodypose_output_acc: 0.6124 - emotion_output_acc: 0.7094 - val_loss: 7.9099 - val_gender_output_loss: 0.6751 - val_imagequality_output_loss: 0.9895 - val_age_output_loss: 1.4508 - val_weight_output_loss: 0.9894 - val_bag_output_loss: 0.9299 - val_footwear_output_loss: 1.0259 - val_bodypose_output_loss: 0.9275 - val_emotion_output_loss: 0.9218 - val_gender_output_acc: 0.5791 - val_imagequality_output_acc: 0.5501 - val_age_output_acc: 0.3890 - val_weight_output_acc: 0.6405 - val_bag_output_acc: 0.5580 - val_footwear_output_acc: 0.4966 - val_bodypose_output_acc: 0.6046 - val_emotion_output_acc: 0.7112
# Epoch 7/20
# 91/91 [==============================] - 118s 1s/step - loss: 8.0455 - gender_output_loss: 0.6850 - imagequality_output_loss: 1.0046 - age_output_loss: 1.4699 - weight_output_loss: 1.0223 - bag_output_loss: 0.9369 - footwear_output_loss: 1.0393 - bodypose_output_loss: 0.9351 - emotion_output_loss: 0.9525 - gender_output_acc: 0.5637 - imagequality_output_acc: 0.5304 - age_output_acc: 0.3756 - weight_output_acc: 0.6293 - bag_output_acc: 0.5423 - footwear_output_acc: 0.4665 - bodypose_output_acc: 0.6161 - emotion_output_acc: 0.7099 - val_loss: 7.8718 - val_gender_output_loss: 0.6727 - val_imagequality_output_loss: 0.9857 - val_age_output_loss: 1.4440 - val_weight_output_loss: 0.9885 - val_bag_output_loss: 0.9280 - val_footwear_output_loss: 1.0154 - val_bodypose_output_loss: 0.9216 - val_emotion_output_loss: 0.9161 - val_gender_output_acc: 0.5825 - val_imagequality_output_acc: 0.5447 - val_age_output_acc: 0.3924 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5589 - val_footwear_output_acc: 0.5147 - val_bodypose_output_acc: 0.6066 - val_emotion_output_acc: 0.7112
# Epoch 8/20
# 91/91 [==============================] - 119s 1s/step - loss: 7.9889 - gender_output_loss: 0.6830 - imagequality_output_loss: 1.0004 - age_output_loss: 1.4597 - weight_output_loss: 1.0133 - bag_output_loss: 0.9318 - footwear_output_loss: 1.0289 - bodypose_output_loss: 0.9307 - emotion_output_loss: 0.9412 - gender_output_acc: 0.5659 - imagequality_output_acc: 0.5322 - age_output_acc: 0.3820 - weight_output_acc: 0.6314 - bag_output_acc: 0.5460 - footwear_output_acc: 0.4851 - bodypose_output_acc: 0.6164 - emotion_output_acc: 0.7121 - val_loss: 7.8162 - val_gender_output_loss: 0.6656 - val_imagequality_output_loss: 0.9800 - val_age_output_loss: 1.4399 - val_weight_output_loss: 0.9847 - val_bag_output_loss: 0.9243 - val_footwear_output_loss: 0.9988 - val_bodypose_output_loss: 0.9112 - val_emotion_output_loss: 0.9116 - val_gender_output_acc: 0.5968 - val_imagequality_output_acc: 0.5506 - val_age_output_acc: 0.3959 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5594 - val_footwear_output_acc: 0.5417 - val_bodypose_output_acc: 0.6056 - val_emotion_output_acc: 0.7112
# Epoch 9/20
# 91/91 [==============================] - 118s 1s/step - loss: 7.9364 - gender_output_loss: 0.6780 - imagequality_output_loss: 0.9911 - age_output_loss: 1.4537 - weight_output_loss: 1.0126 - bag_output_loss: 0.9314 - footwear_output_loss: 1.0169 - bodypose_output_loss: 0.9154 - emotion_output_loss: 0.9374 - gender_output_acc: 0.5745 - imagequality_output_acc: 0.5383 - age_output_acc: 0.3839 - weight_output_acc: 0.6321 - bag_output_acc: 0.5488 - footwear_output_acc: 0.4965 - bodypose_output_acc: 0.6183 - emotion_output_acc: 0.7111 - val_loss: 7.7682 - val_gender_output_loss: 0.6607 - val_imagequality_output_loss: 0.9811 - val_age_output_loss: 1.4341 - val_weight_output_loss: 0.9786 - val_bag_output_loss: 0.9169 - val_footwear_output_loss: 0.9902 - val_bodypose_output_loss: 0.9024 - val_emotion_output_loss: 0.9041 - val_gender_output_acc: 0.6051 - val_imagequality_output_acc: 0.5501 - val_age_output_acc: 0.3944 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5668 - val_footwear_output_acc: 0.5663 - val_bodypose_output_acc: 0.6066 - val_emotion_output_acc: 0.7112
# Epoch 10/20
# 91/91 [==============================] - 119s 1s/step - loss: 7.8844 - gender_output_loss: 0.6679 - imagequality_output_loss: 0.9889 - age_output_loss: 1.4545 - weight_output_loss: 1.0080 - bag_output_loss: 0.9298 - footwear_output_loss: 0.9988 - bodypose_output_loss: 0.9054 - emotion_output_loss: 0.9312 - gender_output_acc: 0.5852 - imagequality_output_acc: 0.5411 - age_output_acc: 0.3804 - weight_output_acc: 0.6306 - bag_output_acc: 0.5521 - footwear_output_acc: 0.5167 - bodypose_output_acc: 0.6182 - emotion_output_acc: 0.7129 - val_loss: 7.7009 - val_gender_output_loss: 0.6451 - val_imagequality_output_loss: 0.9737 - val_age_output_loss: 1.4347 - val_weight_output_loss: 0.9771 - val_bag_output_loss: 0.9111 - val_footwear_output_loss: 0.9680 - val_bodypose_output_loss: 0.8830 - val_emotion_output_loss: 0.9081 - val_gender_output_acc: 0.6135 - val_imagequality_output_acc: 0.5540 - val_age_output_acc: 0.3924 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5693 - val_footwear_output_acc: 0.5776 - val_bodypose_output_acc: 0.6061 - val_emotion_output_acc: 0.7112
# Epoch 11/20
# 91/91 [==============================] - 119s 1s/step - loss: 7.8100 - gender_output_loss: 0.6623 - imagequality_output_loss: 0.9784 - age_output_loss: 1.4477 - weight_output_loss: 1.0030 - bag_output_loss: 0.9184 - footwear_output_loss: 0.9815 - bodypose_output_loss: 0.8930 - emotion_output_loss: 0.9255 - gender_output_acc: 0.5976 - imagequality_output_acc: 0.5459 - age_output_acc: 0.3864 - weight_output_acc: 0.6318 - bag_output_acc: 0.5584 - footwear_output_acc: 0.5317 - bodypose_output_acc: 0.6193 - emotion_output_acc: 0.7112 - val_loss: 7.6392 - val_gender_output_loss: 0.6347 - val_imagequality_output_loss: 0.9755 - val_age_output_loss: 1.4269 - val_weight_output_loss: 0.9778 - val_bag_output_loss: 0.9074 - val_footwear_output_loss: 0.9491 - val_bodypose_output_loss: 0.8652 - val_emotion_output_loss: 0.9025 - val_gender_output_acc: 0.6238 - val_imagequality_output_acc: 0.5530 - val_age_output_acc: 0.3998 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5668 - val_footwear_output_acc: 0.5806 - val_bodypose_output_acc: 0.6061 - val_emotion_output_acc: 0.7112
# Epoch 12/20
# 91/91 [==============================] - 118s 1s/step - loss: 7.7397 - gender_output_loss: 0.6503 - imagequality_output_loss: 0.9758 - age_output_loss: 1.4375 - weight_output_loss: 0.9973 - bag_output_loss: 0.9179 - footwear_output_loss: 0.9547 - bodypose_output_loss: 0.8777 - emotion_output_loss: 0.9284 - gender_output_acc: 0.6110 - imagequality_output_acc: 0.5472 - age_output_acc: 0.3889 - weight_output_acc: 0.6320 - bag_output_acc: 0.5617 - footwear_output_acc: 0.5599 - bodypose_output_acc: 0.6207 - emotion_output_acc: 0.7106 - val_loss: 7.5545 - val_gender_output_loss: 0.6163 - val_imagequality_output_loss: 0.9653 - val_age_output_loss: 1.4287 - val_weight_output_loss: 0.9773 - val_bag_output_loss: 0.8996 - val_footwear_output_loss: 0.9229 - val_bodypose_output_loss: 0.8412 - val_emotion_output_loss: 0.9034 - val_gender_output_acc: 0.6645 - val_imagequality_output_acc: 0.5535 - val_age_output_acc: 0.3969 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5712 - val_footwear_output_acc: 0.5850 - val_bodypose_output_acc: 0.6061 - val_emotion_output_acc: 0.7112
# Epoch 13/20
# 91/91 [==============================] - 118s 1s/step - loss: 7.6397 - gender_output_loss: 0.6343 - imagequality_output_loss: 0.9651 - age_output_loss: 1.4356 - weight_output_loss: 0.9930 - bag_output_loss: 0.9095 - footwear_output_loss: 0.9399 - bodypose_output_loss: 0.8481 - emotion_output_loss: 0.9142 - gender_output_acc: 0.6361 - imagequality_output_acc: 0.5471 - age_output_acc: 0.3905 - weight_output_acc: 0.6340 - bag_output_acc: 0.5611 - footwear_output_acc: 0.5687 - bodypose_output_acc: 0.6258 - emotion_output_acc: 0.7134 - val_loss: 7.4260 - val_gender_output_loss: 0.5897 - val_imagequality_output_loss: 0.9580 - val_age_output_loss: 1.4180 - val_weight_output_loss: 0.9763 - val_bag_output_loss: 0.8924 - val_footwear_output_loss: 0.8990 - val_bodypose_output_loss: 0.7929 - val_emotion_output_loss: 0.8997 - val_gender_output_acc: 0.7004 - val_imagequality_output_acc: 0.5560 - val_age_output_acc: 0.3988 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5786 - val_footwear_output_acc: 0.5761 - val_bodypose_output_acc: 0.6179 - val_emotion_output_acc: 0.7112
# Epoch 14/20
# 91/91 [==============================] - 118s 1s/step - loss: 7.5660 - gender_output_loss: 0.6137 - imagequality_output_loss: 0.9669 - age_output_loss: 1.4342 - weight_output_loss: 0.9930 - bag_output_loss: 0.9022 - footwear_output_loss: 0.9268 - bodypose_output_loss: 0.8174 - emotion_output_loss: 0.9118 - gender_output_acc: 0.6586 - imagequality_output_acc: 0.5442 - age_output_acc: 0.3901 - weight_output_acc: 0.6341 - bag_output_acc: 0.5690 - footwear_output_acc: 0.5770 - bodypose_output_acc: 0.6337 - emotion_output_acc: 0.7123 - val_loss: 7.3456 - val_gender_output_loss: 0.5675 - val_imagequality_output_loss: 0.9548 - val_age_output_loss: 1.4153 - val_weight_output_loss: 0.9696 - val_bag_output_loss: 0.8891 - val_footwear_output_loss: 0.8894 - val_bodypose_output_loss: 0.7661 - val_emotion_output_loss: 0.8937 - val_gender_output_acc: 0.7151 - val_imagequality_output_acc: 0.5496 - val_age_output_acc: 0.3978 - val_weight_output_acc: 0.6415 - val_bag_output_acc: 0.5855 - val_footwear_output_acc: 0.5860 - val_bodypose_output_acc: 0.6375 - val_emotion_output_acc: 0.7112
# Epoch 15/20
# 91/91 [==============================] - 119s 1s/step - loss: 7.4684 - gender_output_loss: 0.5865 - imagequality_output_loss: 0.9623 - age_output_loss: 1.4286 - weight_output_loss: 0.9938 - bag_output_loss: 0.8950 - footwear_output_loss: 0.9114 - bodypose_output_loss: 0.7822 - emotion_output_loss: 0.9087 - gender_output_acc: 0.6872 - imagequality_output_acc: 0.5524 - age_output_acc: 0.3934 - weight_output_acc: 0.6324 - bag_output_acc: 0.5821 - footwear_output_acc: 0.5838 - bodypose_output_acc: 0.6529 - emotion_output_acc: 0.7117 - val_loss: 7.2305 - val_gender_output_loss: 0.5326 - val_imagequality_output_loss: 0.9489 - val_age_output_loss: 1.4100 - val_weight_output_loss: 0.9734 - val_bag_output_loss: 0.8806 - val_footwear_output_loss: 0.8682 - val_bodypose_output_loss: 0.7261 - val_emotion_output_loss: 0.8907 - val_gender_output_acc: 0.7451 - val_imagequality_output_acc: 0.5521 - val_age_output_acc: 0.3915 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.5894 - val_footwear_output_acc: 0.5958 - val_bodypose_output_acc: 0.6655 - val_emotion_output_acc: 0.7112
# Epoch 16/20
# 91/91 [==============================] - 118s 1s/step - loss: 7.3625 - gender_output_loss: 0.5610 - imagequality_output_loss: 0.9555 - age_output_loss: 1.4231 - weight_output_loss: 0.9912 - bag_output_loss: 0.8883 - footwear_output_loss: 0.8917 - bodypose_output_loss: 0.7398 - emotion_output_loss: 0.9120 - gender_output_acc: 0.7098 - imagequality_output_acc: 0.5490 - age_output_acc: 0.3969 - weight_output_acc: 0.6335 - bag_output_acc: 0.5816 - footwear_output_acc: 0.5966 - bodypose_output_acc: 0.6740 - emotion_output_acc: 0.7116 - val_loss: 7.1367 - val_gender_output_loss: 0.5054 - val_imagequality_output_loss: 0.9488 - val_age_output_loss: 1.4025 - val_weight_output_loss: 0.9708 - val_bag_output_loss: 0.8724 - val_footwear_output_loss: 0.8544 - val_bodypose_output_loss: 0.6948 - val_emotion_output_loss: 0.8875 - val_gender_output_acc: 0.7515 - val_imagequality_output_acc: 0.5565 - val_age_output_acc: 0.3919 - val_weight_output_acc: 0.6415 - val_bag_output_acc: 0.5977 - val_footwear_output_acc: 0.6056 - val_bodypose_output_acc: 0.6861 - val_emotion_output_acc: 0.7112
# Epoch 17/20
# 91/91 [==============================] - 118s 1s/step - loss: 7.2696 - gender_output_loss: 0.5324 - imagequality_output_loss: 0.9521 - age_output_loss: 1.4215 - weight_output_loss: 0.9818 - bag_output_loss: 0.8852 - footwear_output_loss: 0.8852 - bodypose_output_loss: 0.7105 - emotion_output_loss: 0.9009 - gender_output_acc: 0.7368 - imagequality_output_acc: 0.5474 - age_output_acc: 0.3874 - weight_output_acc: 0.6368 - bag_output_acc: 0.5872 - footwear_output_acc: 0.5976 - bodypose_output_acc: 0.6974 - emotion_output_acc: 0.7131 - val_loss: 7.0347 - val_gender_output_loss: 0.4827 - val_imagequality_output_loss: 0.9427 - val_age_output_loss: 1.4005 - val_weight_output_loss: 0.9713 - val_bag_output_loss: 0.8643 - val_footwear_output_loss: 0.8475 - val_bodypose_output_loss: 0.6452 - val_emotion_output_loss: 0.8805 - val_gender_output_acc: 0.7652 - val_imagequality_output_acc: 0.5634 - val_age_output_acc: 0.3915 - val_weight_output_acc: 0.6405 - val_bag_output_acc: 0.5953 - val_footwear_output_acc: 0.6051 - val_bodypose_output_acc: 0.7304 - val_emotion_output_acc: 0.7112
# Epoch 18/20
# 91/91 [==============================] - 119s 1s/step - loss: 7.1830 - gender_output_loss: 0.5123 - imagequality_output_loss: 0.9467 - age_output_loss: 1.4170 - weight_output_loss: 0.9827 - bag_output_loss: 0.8773 - footwear_output_loss: 0.8754 - bodypose_output_loss: 0.6706 - emotion_output_loss: 0.9010 - gender_output_acc: 0.7484 - imagequality_output_acc: 0.5458 - age_output_acc: 0.3942 - weight_output_acc: 0.6338 - bag_output_acc: 0.5952 - footwear_output_acc: 0.6019 - bodypose_output_acc: 0.7184 - emotion_output_acc: 0.7105 - val_loss: 6.9607 - val_gender_output_loss: 0.4542 - val_imagequality_output_loss: 0.9322 - val_age_output_loss: 1.3929 - val_weight_output_loss: 0.9644 - val_bag_output_loss: 0.8578 - val_footwear_output_loss: 0.8383 - val_bodypose_output_loss: 0.6461 - val_emotion_output_loss: 0.8747 - val_gender_output_acc: 0.7868 - val_imagequality_output_acc: 0.5604 - val_age_output_acc: 0.3900 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.6100 - val_footwear_output_acc: 0.6179 - val_bodypose_output_acc: 0.7343 - val_emotion_output_acc: 0.7112
# Epoch 19/20
# 91/91 [==============================] - 119s 1s/step - loss: 7.0872 - gender_output_loss: 0.4878 - imagequality_output_loss: 0.9389 - age_output_loss: 1.4109 - weight_output_loss: 0.9824 - bag_output_loss: 0.8691 - footwear_output_loss: 0.8606 - bodypose_output_loss: 0.6438 - emotion_output_loss: 0.8936 - gender_output_acc: 0.7641 - imagequality_output_acc: 0.5477 - age_output_acc: 0.3905 - weight_output_acc: 0.6340 - bag_output_acc: 0.6009 - footwear_output_acc: 0.6098 - bodypose_output_acc: 0.7293 - emotion_output_acc: 0.7139 - val_loss: 6.8610 - val_gender_output_loss: 0.4432 - val_imagequality_output_loss: 0.9251 - val_age_output_loss: 1.3886 - val_weight_output_loss: 0.9635 - val_bag_output_loss: 0.8523 - val_footwear_output_loss: 0.8284 - val_bodypose_output_loss: 0.5901 - val_emotion_output_loss: 0.8697 - val_gender_output_acc: 0.7927 - val_imagequality_output_acc: 0.5639 - val_age_output_acc: 0.3905 - val_weight_output_acc: 0.6419 - val_bag_output_acc: 0.6046 - val_footwear_output_acc: 0.6208 - val_bodypose_output_acc: 0.7696 - val_emotion_output_acc: 0.7112
# Epoch 20/20
# 91/91 [==============================] - 119s 1s/step - loss: 7.0084 - gender_output_loss: 0.4566 - imagequality_output_loss: 0.9327 - age_output_loss: 1.4045 - weight_output_loss: 0.9818 - bag_output_loss: 0.8648 - footwear_output_loss: 0.8573 - bodypose_output_loss: 0.6175 - emotion_output_loss: 0.8932 - gender_output_acc: 0.7873 - imagequality_output_acc: 0.5473 - age_output_acc: 0.3949 - weight_output_acc: 0.6354 - bag_output_acc: 0.6061 - footwear_output_acc: 0.6104 - bodypose_output_acc: 0.7451 - emotion_output_acc: 0.7113 - val_loss: 6.7730 - val_gender_output_loss: 0.4093 - val_imagequality_output_loss: 0.9276 - val_age_output_loss: 1.3818 - val_weight_output_loss: 0.9596 - val_bag_output_loss: 0.8439 - val_footwear_output_loss: 0.8281 - val_bodypose_output_loss: 0.5574 - val_emotion_output_loss: 0.8653 - val_gender_output_acc: 0.8148 - val_imagequality_output_acc: 0.5658 - val_age_output_acc: 0.4018 - val_weight_output_acc: 0.6415 - val_bag_output_acc: 0.6154 - val_footwear_output_acc: 0.6208 - val_bodypose_output_acc: 0.7809 - val_emotion_output_acc: 0.7112

# %%
history2 = model.fit_generator(
  generator=train_gen,
  validation_data=valid_gen,
  epochs=20,
  callbacks=[clr]
)
# Out:
# Epoch 1/20
# 91/91 [==============================] - 122s 1s/step - loss: 6.9282 - gender_output_loss: 0.4354 - imagequality_output_loss: 0.9284 - age_output_loss: 1.3997 - weight_output_loss: 0.9786 - bag_output_loss: 0.8590 - footwear_output_loss: 0.8486 - bodypose_output_loss: 0.5904 - emotion_output_loss: 0.8881 - gender_output_acc: 0.8001 - imagequality_output_acc: 0.5549 - age_output_acc: 0.3923 - weight_output_acc: 0.6334 - bag_output_acc: 0.6070 - footwear_output_acc: 0.6134 - bodypose_output_acc: 0.7625 - emotion_output_acc: 0.7133 - val_loss: 6.7412 - val_gender_output_loss: 0.3994 - val_imagequality_output_loss: 0.9263 - val_age_output_loss: 1.3834 - val_weight_output_loss: 0.9637 - val_bag_output_loss: 0.8383 - val_footwear_output_loss: 0.8337 - val_bodypose_output_loss: 0.5320 - val_emotion_output_loss: 0.8643 - val_gender_output_acc: 0.8207 - val_imagequality_output_acc: 0.5560 - val_age_output_acc: 0.3959 - val_weight_output_acc: 0.6405 - val_bag_output_acc: 0.6228 - val_footwear_output_acc: 0.6154 - val_bodypose_output_acc: 0.7937 - val_emotion_output_acc: 0.7112
# Epoch 2/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.8578 - gender_output_loss: 0.4241 - imagequality_output_loss: 0.9216 - age_output_loss: 1.3963 - weight_output_loss: 0.9733 - bag_output_loss: 0.8509 - footwear_output_loss: 0.8380 - bodypose_output_loss: 0.5684 - emotion_output_loss: 0.8852 - gender_output_acc: 0.8074 - imagequality_output_acc: 0.5554 - age_output_acc: 0.3974 - weight_output_acc: 0.6358 - bag_output_acc: 0.6231 - footwear_output_acc: 0.6195 - bodypose_output_acc: 0.7720 - emotion_output_acc: 0.7116 - val_loss: 6.6757 - val_gender_output_loss: 0.3760 - val_imagequality_output_loss: 0.9368 - val_age_output_loss: 1.3734 - val_weight_output_loss: 0.9589 - val_bag_output_loss: 0.8331 - val_footwear_output_loss: 0.8241 - val_bodypose_output_loss: 0.5127 - val_emotion_output_loss: 0.8607 - val_gender_output_acc: 0.8360 - val_imagequality_output_acc: 0.5526 - val_age_output_acc: 0.4028 - val_weight_output_acc: 0.6429 - val_bag_output_acc: 0.6238 - val_footwear_output_acc: 0.6208 - val_bodypose_output_acc: 0.8021 - val_emotion_output_acc: 0.7112
# Epoch 3/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.7739 - gender_output_loss: 0.3998 - imagequality_output_loss: 0.9160 - age_output_loss: 1.3904 - weight_output_loss: 0.9722 - bag_output_loss: 0.8426 - footwear_output_loss: 0.8275 - bodypose_output_loss: 0.5482 - emotion_output_loss: 0.8773 - gender_output_acc: 0.8214 - imagequality_output_acc: 0.5569 - age_output_acc: 0.3979 - weight_output_acc: 0.6361 - bag_output_acc: 0.6251 - footwear_output_acc: 0.6287 - bodypose_output_acc: 0.7841 - emotion_output_acc: 0.7129 - val_loss: 6.5940 - val_gender_output_loss: 0.3579 - val_imagequality_output_loss: 0.9195 - val_age_output_loss: 1.3704 - val_weight_output_loss: 0.9593 - val_bag_output_loss: 0.8228 - val_footwear_output_loss: 0.8143 - val_bodypose_output_loss: 0.4922 - val_emotion_output_loss: 0.8576 - val_gender_output_acc: 0.8512 - val_imagequality_output_acc: 0.5594 - val_age_output_acc: 0.4032 - val_weight_output_acc: 0.6449 - val_bag_output_acc: 0.6400 - val_footwear_output_acc: 0.6194 - val_bodypose_output_acc: 0.8099 - val_emotion_output_acc: 0.7112
# Epoch 4/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.7166 - gender_output_loss: 0.3824 - imagequality_output_loss: 0.9120 - age_output_loss: 1.3816 - weight_output_loss: 0.9712 - bag_output_loss: 0.8418 - footwear_output_loss: 0.8243 - bodypose_output_loss: 0.5279 - emotion_output_loss: 0.8754 - gender_output_acc: 0.8306 - imagequality_output_acc: 0.5570 - age_output_acc: 0.3948 - weight_output_acc: 0.6354 - bag_output_acc: 0.6283 - footwear_output_acc: 0.6288 - bodypose_output_acc: 0.7939 - emotion_output_acc: 0.7127 - val_loss: 6.5060 - val_gender_output_loss: 0.3482 - val_imagequality_output_loss: 0.8869 - val_age_output_loss: 1.3643 - val_weight_output_loss: 0.9513 - val_bag_output_loss: 0.8229 - val_footwear_output_loss: 0.8044 - val_bodypose_output_loss: 0.4732 - val_emotion_output_loss: 0.8549 - val_gender_output_acc: 0.8443 - val_imagequality_output_acc: 0.5904 - val_age_output_acc: 0.3988 - val_weight_output_acc: 0.6459 - val_bag_output_acc: 0.6306 - val_footwear_output_acc: 0.6419 - val_bodypose_output_acc: 0.8212 - val_emotion_output_acc: 0.7112
# Epoch 5/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.6499 - gender_output_loss: 0.3663 - imagequality_output_loss: 0.9013 - age_output_loss: 1.3794 - weight_output_loss: 0.9670 - bag_output_loss: 0.8321 - footwear_output_loss: 0.8127 - bodypose_output_loss: 0.5138 - emotion_output_loss: 0.8773 - gender_output_acc: 0.8413 - imagequality_output_acc: 0.5634 - age_output_acc: 0.4032 - weight_output_acc: 0.6364 - bag_output_acc: 0.6337 - footwear_output_acc: 0.6337 - bodypose_output_acc: 0.7962 - emotion_output_acc: 0.7124 - val_loss: 6.4700 - val_gender_output_loss: 0.3396 - val_imagequality_output_loss: 0.8847 - val_age_output_loss: 1.3589 - val_weight_output_loss: 0.9469 - val_bag_output_loss: 0.8181 - val_footwear_output_loss: 0.8043 - val_bodypose_output_loss: 0.4626 - val_emotion_output_loss: 0.8549 - val_gender_output_acc: 0.8561 - val_imagequality_output_acc: 0.5761 - val_age_output_acc: 0.4082 - val_weight_output_acc: 0.6429 - val_bag_output_acc: 0.6400 - val_footwear_output_acc: 0.6370 - val_bodypose_output_acc: 0.8306 - val_emotion_output_acc: 0.7112
# Epoch 6/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.5958 - gender_output_loss: 0.3492 - imagequality_output_loss: 0.9036 - age_output_loss: 1.3751 - weight_output_loss: 0.9682 - bag_output_loss: 0.8285 - footwear_output_loss: 0.8094 - bodypose_output_loss: 0.4872 - emotion_output_loss: 0.8746 - gender_output_acc: 0.8494 - imagequality_output_acc: 0.5570 - age_output_acc: 0.4071 - weight_output_acc: 0.6341 - bag_output_acc: 0.6407 - footwear_output_acc: 0.6395 - bodypose_output_acc: 0.8140 - emotion_output_acc: 0.7119 - val_loss: 6.4272 - val_gender_output_loss: 0.3312 - val_imagequality_output_loss: 0.8988 - val_age_output_loss: 1.3513 - val_weight_output_loss: 0.9448 - val_bag_output_loss: 0.8125 - val_footwear_output_loss: 0.8018 - val_bodypose_output_loss: 0.4311 - val_emotion_output_loss: 0.8557 - val_gender_output_acc: 0.8649 - val_imagequality_output_acc: 0.5648 - val_age_output_acc: 0.4067 - val_weight_output_acc: 0.6454 - val_bag_output_acc: 0.6503 - val_footwear_output_acc: 0.6419 - val_bodypose_output_acc: 0.8409 - val_emotion_output_acc: 0.7117
# Epoch 7/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.5202 - gender_output_loss: 0.3388 - imagequality_output_loss: 0.8943 - age_output_loss: 1.3708 - weight_output_loss: 0.9652 - bag_output_loss: 0.8153 - footwear_output_loss: 0.8036 - bodypose_output_loss: 0.4662 - emotion_output_loss: 0.8661 - gender_output_acc: 0.8532 - imagequality_output_acc: 0.5639 - age_output_acc: 0.4042 - weight_output_acc: 0.6356 - bag_output_acc: 0.6421 - footwear_output_acc: 0.6416 - bodypose_output_acc: 0.8237 - emotion_output_acc: 0.7131 - val_loss: 6.3833 - val_gender_output_loss: 0.3315 - val_imagequality_output_loss: 0.8794 - val_age_output_loss: 1.3505 - val_weight_output_loss: 0.9480 - val_bag_output_loss: 0.7997 - val_footwear_output_loss: 0.7975 - val_bodypose_output_loss: 0.4205 - val_emotion_output_loss: 0.8562 - val_gender_output_acc: 0.8551 - val_imagequality_output_acc: 0.5840 - val_age_output_acc: 0.4086 - val_weight_output_acc: 0.6424 - val_bag_output_acc: 0.6523 - val_footwear_output_acc: 0.6415 - val_bodypose_output_acc: 0.8482 - val_emotion_output_acc: 0.7117
# Epoch 8/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.4614 - gender_output_loss: 0.3257 - imagequality_output_loss: 0.8951 - age_output_loss: 1.3609 - weight_output_loss: 0.9534 - bag_output_loss: 0.8109 - footwear_output_loss: 0.7999 - bodypose_output_loss: 0.4477 - emotion_output_loss: 0.8678 - gender_output_acc: 0.8650 - imagequality_output_acc: 0.5666 - age_output_acc: 0.4104 - weight_output_acc: 0.6350 - bag_output_acc: 0.6452 - footwear_output_acc: 0.6437 - bodypose_output_acc: 0.8312 - emotion_output_acc: 0.7113 - val_loss: 6.4008 - val_gender_output_loss: 0.3171 - val_imagequality_output_loss: 0.8996 - val_age_output_loss: 1.3498 - val_weight_output_loss: 0.9499 - val_bag_output_loss: 0.7939 - val_footwear_output_loss: 0.7954 - val_bodypose_output_loss: 0.4408 - val_emotion_output_loss: 0.8543 - val_gender_output_acc: 0.8664 - val_imagequality_output_acc: 0.5555 - val_age_output_acc: 0.3959 - val_weight_output_acc: 0.6434 - val_bag_output_acc: 0.6626 - val_footwear_output_acc: 0.6444 - val_bodypose_output_acc: 0.8409 - val_emotion_output_acc: 0.7117
# Epoch 9/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.4244 - gender_output_loss: 0.3097 - imagequality_output_loss: 0.8895 - age_output_loss: 1.3585 - weight_output_loss: 0.9511 - bag_output_loss: 0.8030 - footwear_output_loss: 0.8010 - bodypose_output_loss: 0.4466 - emotion_output_loss: 0.8650 - gender_output_acc: 0.8715 - imagequality_output_acc: 0.5708 - age_output_acc: 0.4085 - weight_output_acc: 0.6385 - bag_output_acc: 0.6557 - footwear_output_acc: 0.6436 - bodypose_output_acc: 0.8329 - emotion_output_acc: 0.7121 - val_loss: 6.2909 - val_gender_output_loss: 0.3069 - val_imagequality_output_loss: 0.8669 - val_age_output_loss: 1.3402 - val_weight_output_loss: 0.9381 - val_bag_output_loss: 0.7859 - val_footwear_output_loss: 0.7866 - val_bodypose_output_loss: 0.4130 - val_emotion_output_loss: 0.8532 - val_gender_output_acc: 0.8733 - val_imagequality_output_acc: 0.5904 - val_age_output_acc: 0.4082 - val_weight_output_acc: 0.6464 - val_bag_output_acc: 0.6650 - val_footwear_output_acc: 0.6469 - val_bodypose_output_acc: 0.8487 - val_emotion_output_acc: 0.7117
# Epoch 10/20
# 91/91 [==============================] - 117s 1s/step - loss: 6.3573 - gender_output_loss: 0.3078 - imagequality_output_loss: 0.8814 - age_output_loss: 1.3517 - weight_output_loss: 0.9459 - bag_output_loss: 0.7912 - footwear_output_loss: 0.7818 - bodypose_output_loss: 0.4321 - emotion_output_loss: 0.8655 - gender_output_acc: 0.8726 - imagequality_output_acc: 0.5779 - age_output_acc: 0.4110 - weight_output_acc: 0.6397 - bag_output_acc: 0.6610 - footwear_output_acc: 0.6518 - bodypose_output_acc: 0.8380 - emotion_output_acc: 0.7120 - val_loss: 6.3801 - val_gender_output_loss: 0.3109 - val_imagequality_output_loss: 0.9335 - val_age_output_loss: 1.3313 - val_weight_output_loss: 0.9368 - val_bag_output_loss: 0.7952 - val_footwear_output_loss: 0.7929 - val_bodypose_output_loss: 0.4250 - val_emotion_output_loss: 0.8545 - val_gender_output_acc: 0.8787 - val_imagequality_output_acc: 0.5265 - val_age_output_acc: 0.4165 - val_weight_output_acc: 0.6464 - val_bag_output_acc: 0.6670 - val_footwear_output_acc: 0.6361 - val_bodypose_output_acc: 0.8527 - val_emotion_output_acc: 0.7117
# Epoch 11/20
# 91/91 [==============================] - 117s 1s/step - loss: 6.3130 - gender_output_loss: 0.2966 - imagequality_output_loss: 0.8822 - age_output_loss: 1.3395 - weight_output_loss: 0.9408 - bag_output_loss: 0.7886 - footwear_output_loss: 0.7854 - bodypose_output_loss: 0.4147 - emotion_output_loss: 0.8651 - gender_output_acc: 0.8777 - imagequality_output_acc: 0.5713 - age_output_acc: 0.4162 - weight_output_acc: 0.6399 - bag_output_acc: 0.6647 - footwear_output_acc: 0.6506 - bodypose_output_acc: 0.8489 - emotion_output_acc: 0.7112 - val_loss: 6.2897 - val_gender_output_loss: 0.2932 - val_imagequality_output_loss: 0.9274 - val_age_output_loss: 1.3252 - val_weight_output_loss: 0.9356 - val_bag_output_loss: 0.7702 - val_footwear_output_loss: 0.7857 - val_bodypose_output_loss: 0.3943 - val_emotion_output_loss: 0.8582 - val_gender_output_acc: 0.8782 - val_imagequality_output_acc: 0.5339 - val_age_output_acc: 0.4140 - val_weight_output_acc: 0.6488 - val_bag_output_acc: 0.6793 - val_footwear_output_acc: 0.6473 - val_bodypose_output_acc: 0.8620 - val_emotion_output_acc: 0.7122
# Epoch 12/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.2527 - gender_output_loss: 0.2854 - imagequality_output_loss: 0.8790 - age_output_loss: 1.3325 - weight_output_loss: 0.9369 - bag_output_loss: 0.7755 - footwear_output_loss: 0.7739 - bodypose_output_loss: 0.4096 - emotion_output_loss: 0.8600 - gender_output_acc: 0.8832 - imagequality_output_acc: 0.5765 - age_output_acc: 0.4161 - weight_output_acc: 0.6405 - bag_output_acc: 0.6758 - footwear_output_acc: 0.6564 - bodypose_output_acc: 0.8497 - emotion_output_acc: 0.7137 - val_loss: 6.2468 - val_gender_output_loss: 0.2883 - val_imagequality_output_loss: 0.9151 - val_age_output_loss: 1.3155 - val_weight_output_loss: 0.9300 - val_bag_output_loss: 0.7694 - val_footwear_output_loss: 0.7814 - val_bodypose_output_loss: 0.3942 - val_emotion_output_loss: 0.8528 - val_gender_output_acc: 0.8870 - val_imagequality_output_acc: 0.5457 - val_age_output_acc: 0.4190 - val_weight_output_acc: 0.6513 - val_bag_output_acc: 0.6763 - val_footwear_output_acc: 0.6503 - val_bodypose_output_acc: 0.8600 - val_emotion_output_acc: 0.7117
# Epoch 13/20
# 91/91 [==============================] - 117s 1s/step - loss: 6.2169 - gender_output_loss: 0.2778 - imagequality_output_loss: 0.8756 - age_output_loss: 1.3258 - weight_output_loss: 0.9307 - bag_output_loss: 0.7684 - footwear_output_loss: 0.7737 - bodypose_output_loss: 0.4082 - emotion_output_loss: 0.8568 - gender_output_acc: 0.8862 - imagequality_output_acc: 0.5785 - age_output_acc: 0.4221 - weight_output_acc: 0.6407 - bag_output_acc: 0.6770 - footwear_output_acc: 0.6606 - bodypose_output_acc: 0.8510 - emotion_output_acc: 0.7126 - val_loss: 6.2316 - val_gender_output_loss: 0.2797 - val_imagequality_output_loss: 0.9006 - val_age_output_loss: 1.3162 - val_weight_output_loss: 0.9306 - val_bag_output_loss: 0.7728 - val_footwear_output_loss: 0.7866 - val_bodypose_output_loss: 0.3923 - val_emotion_output_loss: 0.8529 - val_gender_output_acc: 0.8924 - val_imagequality_output_acc: 0.5619 - val_age_output_acc: 0.4175 - val_weight_output_acc: 0.6513 - val_bag_output_acc: 0.6749 - val_footwear_output_acc: 0.6611 - val_bodypose_output_acc: 0.8605 - val_emotion_output_acc: 0.7117
# Epoch 14/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.1705 - gender_output_loss: 0.2698 - imagequality_output_loss: 0.8741 - age_output_loss: 1.3146 - weight_output_loss: 0.9283 - bag_output_loss: 0.7641 - footwear_output_loss: 0.7680 - bodypose_output_loss: 0.3966 - emotion_output_loss: 0.8550 - gender_output_acc: 0.8921 - imagequality_output_acc: 0.5736 - age_output_acc: 0.4243 - weight_output_acc: 0.6419 - bag_output_acc: 0.6789 - footwear_output_acc: 0.6600 - bodypose_output_acc: 0.8555 - emotion_output_acc: 0.7129 - val_loss: 6.2138 - val_gender_output_loss: 0.2785 - val_imagequality_output_loss: 0.9132 - val_age_output_loss: 1.3047 - val_weight_output_loss: 0.9267 - val_bag_output_loss: 0.7616 - val_footwear_output_loss: 0.7829 - val_bodypose_output_loss: 0.3907 - val_emotion_output_loss: 0.8555 - val_gender_output_acc: 0.8954 - val_imagequality_output_acc: 0.5437 - val_age_output_acc: 0.4253 - val_weight_output_acc: 0.6513 - val_bag_output_acc: 0.6822 - val_footwear_output_acc: 0.6552 - val_bodypose_output_acc: 0.8654 - val_emotion_output_acc: 0.7127
# Epoch 15/20
# 91/91 [==============================] - 118s 1s/step - loss: 6.0961 - gender_output_loss: 0.2513 - imagequality_output_loss: 0.8706 - age_output_loss: 1.3159 - weight_output_loss: 0.9180 - bag_output_loss: 0.7481 - footwear_output_loss: 0.7586 - bodypose_output_loss: 0.3778 - emotion_output_loss: 0.8558 - gender_output_acc: 0.9027 - imagequality_output_acc: 0.5808 - age_output_acc: 0.4205 - weight_output_acc: 0.6464 - bag_output_acc: 0.6892 - footwear_output_acc: 0.6625 - bodypose_output_acc: 0.8590 - emotion_output_acc: 0.7120 - val_loss: 6.2398 - val_gender_output_loss: 0.2811 - val_imagequality_output_loss: 0.9386 - val_age_output_loss: 1.3010 - val_weight_output_loss: 0.9240 - val_bag_output_loss: 0.7582 - val_footwear_output_loss: 0.7914 - val_bodypose_output_loss: 0.3904 - val_emotion_output_loss: 0.8551 - val_gender_output_acc: 0.8959 - val_imagequality_output_acc: 0.5270 - val_age_output_acc: 0.4263 - val_weight_output_acc: 0.6503 - val_bag_output_acc: 0.6886 - val_footwear_output_acc: 0.6380 - val_bodypose_output_acc: 0.8610 - val_emotion_output_acc: 0.7112
# Epoch 16/20
# 91/91 [==============================] - 117s 1s/step - loss: 6.0663 - gender_output_loss: 0.2485 - imagequality_output_loss: 0.8633 - age_output_loss: 1.3063 - weight_output_loss: 0.9063 - bag_output_loss: 0.7463 - footwear_output_loss: 0.7617 - bodypose_output_loss: 0.3802 - emotion_output_loss: 0.8538 - gender_output_acc: 0.8996 - imagequality_output_acc: 0.5821 - age_output_acc: 0.4212 - weight_output_acc: 0.6441 - bag_output_acc: 0.6955 - footwear_output_acc: 0.6641 - bodypose_output_acc: 0.8621 - emotion_output_acc: 0.7116 - val_loss: 6.2355 - val_gender_output_loss: 0.2857 - val_imagequality_output_loss: 0.9363 - val_age_output_loss: 1.3091 - val_weight_output_loss: 0.9219 - val_bag_output_loss: 0.7595 - val_footwear_output_loss: 0.7824 - val_bodypose_output_loss: 0.3875 - val_emotion_output_loss: 0.8532 - val_gender_output_acc: 0.8870 - val_imagequality_output_acc: 0.5265 - val_age_output_acc: 0.4170 - val_weight_output_acc: 0.6429 - val_bag_output_acc: 0.6832 - val_footwear_output_acc: 0.6478 - val_bodypose_output_acc: 0.8669 - val_emotion_output_acc: 0.7127
# Epoch 17/20
# 91/91 [==============================] - 117s 1s/step - loss: 6.0287 - gender_output_loss: 0.2415 - imagequality_output_loss: 0.8662 - age_output_loss: 1.3046 - weight_output_loss: 0.9059 - bag_output_loss: 0.7402 - footwear_output_loss: 0.7521 - bodypose_output_loss: 0.3609 - emotion_output_loss: 0.8573 - gender_output_acc: 0.9048 - imagequality_output_acc: 0.5868 - age_output_acc: 0.4246 - weight_output_acc: 0.6501 - bag_output_acc: 0.6983 - footwear_output_acc: 0.6653 - bodypose_output_acc: 0.8702 - emotion_output_acc: 0.7105 - val_loss: 6.1618 - val_gender_output_loss: 0.2779 - val_imagequality_output_loss: 0.8978 - val_age_output_loss: 1.2948 - val_weight_output_loss: 0.9207 - val_bag_output_loss: 0.7587 - val_footwear_output_loss: 0.7837 - val_bodypose_output_loss: 0.3766 - val_emotion_output_loss: 0.8516 - val_gender_output_acc: 0.8905 - val_imagequality_output_acc: 0.5521 - val_age_output_acc: 0.4273 - val_weight_output_acc: 0.6557 - val_bag_output_acc: 0.6837 - val_footwear_output_acc: 0.6513 - val_bodypose_output_acc: 0.8703 - val_emotion_output_acc: 0.7132
# Epoch 18/20
# 91/91 [==============================] - 116s 1s/step - loss: 5.9725 - gender_output_loss: 0.2364 - imagequality_output_loss: 0.8588 - age_output_loss: 1.2929 - weight_output_loss: 0.8939 - bag_output_loss: 0.7304 - footwear_output_loss: 0.7475 - bodypose_output_loss: 0.3560 - emotion_output_loss: 0.8568 - gender_output_acc: 0.9081 - imagequality_output_acc: 0.5867 - age_output_acc: 0.4288 - weight_output_acc: 0.6506 - bag_output_acc: 0.7014 - footwear_output_acc: 0.6738 - bodypose_output_acc: 0.8722 - emotion_output_acc: 0.7098 - val_loss: 6.1825 - val_gender_output_loss: 0.2712 - val_imagequality_output_loss: 0.9232 - val_age_output_loss: 1.2911 - val_weight_output_loss: 0.9130 - val_bag_output_loss: 0.7435 - val_footwear_output_loss: 0.7936 - val_bodypose_output_loss: 0.3917 - val_emotion_output_loss: 0.8552 - val_gender_output_acc: 0.8988 - val_imagequality_output_acc: 0.5270 - val_age_output_acc: 0.4307 - val_weight_output_acc: 0.6439 - val_bag_output_acc: 0.6955 - val_footwear_output_acc: 0.6513 - val_bodypose_output_acc: 0.8590 - val_emotion_output_acc: 0.7132
# Epoch 19/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.9206 - gender_output_loss: 0.2290 - imagequality_output_loss: 0.8573 - age_output_loss: 1.2868 - weight_output_loss: 0.8858 - bag_output_loss: 0.7237 - footwear_output_loss: 0.7437 - bodypose_output_loss: 0.3483 - emotion_output_loss: 0.8459 - gender_output_acc: 0.9078 - imagequality_output_acc: 0.5869 - age_output_acc: 0.4261 - weight_output_acc: 0.6519 - bag_output_acc: 0.7041 - footwear_output_acc: 0.6734 - bodypose_output_acc: 0.8767 - emotion_output_acc: 0.7122 - val_loss: 6.1484 - val_gender_output_loss: 0.2853 - val_imagequality_output_loss: 0.8738 - val_age_output_loss: 1.2948 - val_weight_output_loss: 0.9091 - val_bag_output_loss: 0.7625 - val_footwear_output_loss: 0.7882 - val_bodypose_output_loss: 0.3876 - val_emotion_output_loss: 0.8471 - val_gender_output_acc: 0.8988 - val_imagequality_output_acc: 0.5560 - val_age_output_acc: 0.4293 - val_weight_output_acc: 0.6518 - val_bag_output_acc: 0.6842 - val_footwear_output_acc: 0.6508 - val_bodypose_output_acc: 0.8635 - val_emotion_output_acc: 0.7137
# Epoch 20/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.8957 - gender_output_loss: 0.2178 - imagequality_output_loss: 0.8580 - age_output_loss: 1.2820 - weight_output_loss: 0.8813 - bag_output_loss: 0.7178 - footwear_output_loss: 0.7429 - bodypose_output_loss: 0.3478 - emotion_output_loss: 0.8481 - gender_output_acc: 0.9135 - imagequality_output_acc: 0.5901 - age_output_acc: 0.4334 - weight_output_acc: 0.6567 - bag_output_acc: 0.7047 - footwear_output_acc: 0.6690 - bodypose_output_acc: 0.8742 - emotion_output_acc: 0.7102 - val_loss: 6.1953 - val_gender_output_loss: 0.2698 - val_imagequality_output_loss: 0.9040 - val_age_output_loss: 1.3218 - val_weight_output_loss: 0.9253 - val_bag_output_loss: 0.7501 - val_footwear_output_loss: 0.7809 - val_bodypose_output_loss: 0.3893 - val_emotion_output_loss: 0.8541 - val_gender_output_acc: 0.8870 - val_imagequality_output_acc: 0.5472 - val_age_output_acc: 0.4150 - val_weight_output_acc: 0.6203 - val_bag_output_acc: 0.7014 - val_footwear_output_acc: 0.6503 - val_bodypose_output_acc: 0.8630 - val_emotion_output_acc: 0.7122

# %%
clr = CyclicLR(base_lr=0.0001, max_lr=.001, step_size=7220)

# %%
history3 = model.fit_generator(
  generator=train_gen,
  validation_data=valid_gen,
  epochs=20,
  callbacks=[clr]
)
# Out:
# Epoch 1/20
# 91/91 [==============================] - 120s 1s/step - loss: 5.8215 - gender_output_loss: 0.2157 - imagequality_output_loss: 0.8485 - age_output_loss: 1.2749 - weight_output_loss: 0.8690 - bag_output_loss: 0.7078 - footwear_output_loss: 0.7344 - bodypose_output_loss: 0.3282 - emotion_output_loss: 0.8430 - gender_output_acc: 0.9166 - imagequality_output_acc: 0.5905 - age_output_acc: 0.4382 - weight_output_acc: 0.6631 - bag_output_acc: 0.7148 - footwear_output_acc: 0.6756 - bodypose_output_acc: 0.8815 - emotion_output_acc: 0.7120 - val_loss: 6.1159 - val_gender_output_loss: 0.2599 - val_imagequality_output_loss: 0.9017 - val_age_output_loss: 1.2908 - val_weight_output_loss: 0.9135 - val_bag_output_loss: 0.7433 - val_footwear_output_loss: 0.7773 - val_bodypose_output_loss: 0.3760 - val_emotion_output_loss: 0.8533 - val_gender_output_acc: 0.8988 - val_imagequality_output_acc: 0.5432 - val_age_output_acc: 0.4342 - val_weight_output_acc: 0.6375 - val_bag_output_acc: 0.6999 - val_footwear_output_acc: 0.6626 - val_bodypose_output_acc: 0.8664 - val_emotion_output_acc: 0.7132
# Epoch 2/20
# 91/91 [==============================] - 116s 1s/step - loss: 5.8055 - gender_output_loss: 0.2060 - imagequality_output_loss: 0.8492 - age_output_loss: 1.2625 - weight_output_loss: 0.8692 - bag_output_loss: 0.7050 - footwear_output_loss: 0.7343 - bodypose_output_loss: 0.3338 - emotion_output_loss: 0.8455 - gender_output_acc: 0.9202 - imagequality_output_acc: 0.5870 - age_output_acc: 0.4425 - weight_output_acc: 0.6609 - bag_output_acc: 0.7151 - footwear_output_acc: 0.6781 - bodypose_output_acc: 0.8815 - emotion_output_acc: 0.7123 - val_loss: 6.0966 - val_gender_output_loss: 0.2594 - val_imagequality_output_loss: 0.9023 - val_age_output_loss: 1.2827 - val_weight_output_loss: 0.9106 - val_bag_output_loss: 0.7406 - val_footwear_output_loss: 0.7765 - val_bodypose_output_loss: 0.3707 - val_emotion_output_loss: 0.8537 - val_gender_output_acc: 0.9003 - val_imagequality_output_acc: 0.5432 - val_age_output_acc: 0.4337 - val_weight_output_acc: 0.6410 - val_bag_output_acc: 0.7004 - val_footwear_output_acc: 0.6626 - val_bodypose_output_acc: 0.8689 - val_emotion_output_acc: 0.7137
# Epoch 3/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7999 - gender_output_loss: 0.2033 - imagequality_output_loss: 0.8498 - age_output_loss: 1.2631 - weight_output_loss: 0.8702 - bag_output_loss: 0.7015 - footwear_output_loss: 0.7320 - bodypose_output_loss: 0.3332 - emotion_output_loss: 0.8468 - gender_output_acc: 0.9211 - imagequality_output_acc: 0.5875 - age_output_acc: 0.4405 - weight_output_acc: 0.6572 - bag_output_acc: 0.7193 - footwear_output_acc: 0.6771 - bodypose_output_acc: 0.8814 - emotion_output_acc: 0.7103 - val_loss: 6.0904 - val_gender_output_loss: 0.2596 - val_imagequality_output_loss: 0.9033 - val_age_output_loss: 1.2796 - val_weight_output_loss: 0.9091 - val_bag_output_loss: 0.7395 - val_footwear_output_loss: 0.7764 - val_bodypose_output_loss: 0.3695 - val_emotion_output_loss: 0.8533 - val_gender_output_acc: 0.9028 - val_imagequality_output_acc: 0.5413 - val_age_output_acc: 0.4381 - val_weight_output_acc: 0.6459 - val_bag_output_acc: 0.6960 - val_footwear_output_acc: 0.6621 - val_bodypose_output_acc: 0.8708 - val_emotion_output_acc: 0.7137
# Epoch 4/20
# 91/91 [==============================] - 118s 1s/step - loss: 5.7991 - gender_output_loss: 0.2037 - imagequality_output_loss: 0.8424 - age_output_loss: 1.2582 - weight_output_loss: 0.8759 - bag_output_loss: 0.7034 - footwear_output_loss: 0.7350 - bodypose_output_loss: 0.3354 - emotion_output_loss: 0.8453 - gender_output_acc: 0.9200 - imagequality_output_acc: 0.5953 - age_output_acc: 0.4443 - weight_output_acc: 0.6556 - bag_output_acc: 0.7153 - footwear_output_acc: 0.6761 - bodypose_output_acc: 0.8805 - emotion_output_acc: 0.7115 - val_loss: 6.0936 - val_gender_output_loss: 0.2601 - val_imagequality_output_loss: 0.9085 - val_age_output_loss: 1.2782 - val_weight_output_loss: 0.9085 - val_bag_output_loss: 0.7392 - val_footwear_output_loss: 0.7762 - val_bodypose_output_loss: 0.3695 - val_emotion_output_loss: 0.8534 - val_gender_output_acc: 0.9028 - val_imagequality_output_acc: 0.5413 - val_age_output_acc: 0.4342 - val_weight_output_acc: 0.6473 - val_bag_output_acc: 0.6960 - val_footwear_output_acc: 0.6621 - val_bodypose_output_acc: 0.8689 - val_emotion_output_acc: 0.7137
# Epoch 5/20
# 91/91 [==============================] - 118s 1s/step - loss: 5.7982 - gender_output_loss: 0.2037 - imagequality_output_loss: 0.8442 - age_output_loss: 1.2629 - weight_output_loss: 0.8746 - bag_output_loss: 0.7070 - footwear_output_loss: 0.7359 - bodypose_output_loss: 0.3292 - emotion_output_loss: 0.8406 - gender_output_acc: 0.9220 - imagequality_output_acc: 0.5939 - age_output_acc: 0.4407 - weight_output_acc: 0.6570 - bag_output_acc: 0.7116 - footwear_output_acc: 0.6729 - bodypose_output_acc: 0.8821 - emotion_output_acc: 0.7139 - val_loss: 6.0854 - val_gender_output_loss: 0.2601 - val_imagequality_output_loss: 0.9031 - val_age_output_loss: 1.2771 - val_weight_output_loss: 0.9070 - val_bag_output_loss: 0.7394 - val_footwear_output_loss: 0.7759 - val_bodypose_output_loss: 0.3702 - val_emotion_output_loss: 0.8526 - val_gender_output_acc: 0.9023 - val_imagequality_output_acc: 0.5452 - val_age_output_acc: 0.4361 - val_weight_output_acc: 0.6488 - val_bag_output_acc: 0.6979 - val_footwear_output_acc: 0.6621 - val_bodypose_output_acc: 0.8684 - val_emotion_output_acc: 0.7137
# Epoch 6/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7839 - gender_output_loss: 0.2050 - imagequality_output_loss: 0.8457 - age_output_loss: 1.2598 - weight_output_loss: 0.8716 - bag_output_loss: 0.7044 - footwear_output_loss: 0.7315 - bodypose_output_loss: 0.3243 - emotion_output_loss: 0.8417 - gender_output_acc: 0.9218 - imagequality_output_acc: 0.5909 - age_output_acc: 0.4359 - weight_output_acc: 0.6603 - bag_output_acc: 0.7166 - footwear_output_acc: 0.6797 - bodypose_output_acc: 0.8841 - emotion_output_acc: 0.7127 - val_loss: 6.0936 - val_gender_output_loss: 0.2620 - val_imagequality_output_loss: 0.9069 - val_age_output_loss: 1.2774 - val_weight_output_loss: 0.9083 - val_bag_output_loss: 0.7393 - val_footwear_output_loss: 0.7764 - val_bodypose_output_loss: 0.3706 - val_emotion_output_loss: 0.8529 - val_gender_output_acc: 0.8983 - val_imagequality_output_acc: 0.5408 - val_age_output_acc: 0.4337 - val_weight_output_acc: 0.6483 - val_bag_output_acc: 0.6965 - val_footwear_output_acc: 0.6616 - val_bodypose_output_acc: 0.8703 - val_emotion_output_acc: 0.7137
# Epoch 7/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7736 - gender_output_loss: 0.1997 - imagequality_output_loss: 0.8390 - age_output_loss: 1.2623 - weight_output_loss: 0.8706 - bag_output_loss: 0.7040 - footwear_output_loss: 0.7295 - bodypose_output_loss: 0.3276 - emotion_output_loss: 0.8410 - gender_output_acc: 0.9247 - imagequality_output_acc: 0.5926 - age_output_acc: 0.4388 - weight_output_acc: 0.6550 - bag_output_acc: 0.7138 - footwear_output_acc: 0.6787 - bodypose_output_acc: 0.8809 - emotion_output_acc: 0.7114 - val_loss: 6.1012 - val_gender_output_loss: 0.2633 - val_imagequality_output_loss: 0.9141 - val_age_output_loss: 1.2764 - val_weight_output_loss: 0.9077 - val_bag_output_loss: 0.7394 - val_footwear_output_loss: 0.7770 - val_bodypose_output_loss: 0.3705 - val_emotion_output_loss: 0.8528 - val_gender_output_acc: 0.8978 - val_imagequality_output_acc: 0.5329 - val_age_output_acc: 0.4366 - val_weight_output_acc: 0.6444 - val_bag_output_acc: 0.6955 - val_footwear_output_acc: 0.6645 - val_bodypose_output_acc: 0.8694 - val_emotion_output_acc: 0.7137
# Epoch 8/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7855 - gender_output_loss: 0.2068 - imagequality_output_loss: 0.8457 - age_output_loss: 1.2627 - weight_output_loss: 0.8679 - bag_output_loss: 0.7021 - footwear_output_loss: 0.7232 - bodypose_output_loss: 0.3296 - emotion_output_loss: 0.8474 - gender_output_acc: 0.9222 - imagequality_output_acc: 0.5941 - age_output_acc: 0.4394 - weight_output_acc: 0.6569 - bag_output_acc: 0.7169 - footwear_output_acc: 0.6839 - bodypose_output_acc: 0.8824 - emotion_output_acc: 0.7120 - val_loss: 6.0985 - val_gender_output_loss: 0.2635 - val_imagequality_output_loss: 0.9106 - val_age_output_loss: 1.2765 - val_weight_output_loss: 0.9081 - val_bag_output_loss: 0.7390 - val_footwear_output_loss: 0.7772 - val_bodypose_output_loss: 0.3708 - val_emotion_output_loss: 0.8528 - val_gender_output_acc: 0.8964 - val_imagequality_output_acc: 0.5339 - val_age_output_acc: 0.4337 - val_weight_output_acc: 0.6429 - val_bag_output_acc: 0.6955 - val_footwear_output_acc: 0.6596 - val_bodypose_output_acc: 0.8698 - val_emotion_output_acc: 0.7137
# Epoch 9/20
# 91/91 [==============================] - 116s 1s/step - loss: 5.7700 - gender_output_loss: 0.2063 - imagequality_output_loss: 0.8473 - age_output_loss: 1.2546 - weight_output_loss: 0.8679 - bag_output_loss: 0.7038 - footwear_output_loss: 0.7266 - bodypose_output_loss: 0.3206 - emotion_output_loss: 0.8429 - gender_output_acc: 0.9183 - imagequality_output_acc: 0.5893 - age_output_acc: 0.4464 - weight_output_acc: 0.6590 - bag_output_acc: 0.7187 - footwear_output_acc: 0.6815 - bodypose_output_acc: 0.8873 - emotion_output_acc: 0.7114 - val_loss: 6.1055 - val_gender_output_loss: 0.2635 - val_imagequality_output_loss: 0.9167 - val_age_output_loss: 1.2766 - val_weight_output_loss: 0.9089 - val_bag_output_loss: 0.7379 - val_footwear_output_loss: 0.7779 - val_bodypose_output_loss: 0.3706 - val_emotion_output_loss: 0.8534 - val_gender_output_acc: 0.8988 - val_imagequality_output_acc: 0.5319 - val_age_output_acc: 0.4347 - val_weight_output_acc: 0.6439 - val_bag_output_acc: 0.6960 - val_footwear_output_acc: 0.6586 - val_bodypose_output_acc: 0.8698 - val_emotion_output_acc: 0.7132
# Epoch 10/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7713 - gender_output_loss: 0.2009 - imagequality_output_loss: 0.8463 - age_output_loss: 1.2613 - weight_output_loss: 0.8707 - bag_output_loss: 0.7003 - footwear_output_loss: 0.7284 - bodypose_output_loss: 0.3203 - emotion_output_loss: 0.8431 - gender_output_acc: 0.9246 - imagequality_output_acc: 0.5906 - age_output_acc: 0.4368 - weight_output_acc: 0.6600 - bag_output_acc: 0.7153 - footwear_output_acc: 0.6768 - bodypose_output_acc: 0.8851 - emotion_output_acc: 0.7105 - val_loss: 6.1007 - val_gender_output_loss: 0.2626 - val_imagequality_output_loss: 0.9133 - val_age_output_loss: 1.2771 - val_weight_output_loss: 0.9074 - val_bag_output_loss: 0.7379 - val_footwear_output_loss: 0.7782 - val_bodypose_output_loss: 0.3712 - val_emotion_output_loss: 0.8530 - val_gender_output_acc: 0.8983 - val_imagequality_output_acc: 0.5349 - val_age_output_acc: 0.4322 - val_weight_output_acc: 0.6483 - val_bag_output_acc: 0.6979 - val_footwear_output_acc: 0.6591 - val_bodypose_output_acc: 0.8698 - val_emotion_output_acc: 0.7137
# Epoch 11/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7601 - gender_output_loss: 0.1976 - imagequality_output_loss: 0.8424 - age_output_loss: 1.2590 - weight_output_loss: 0.8706 - bag_output_loss: 0.6950 - footwear_output_loss: 0.7295 - bodypose_output_loss: 0.3246 - emotion_output_loss: 0.8413 - gender_output_acc: 0.9226 - imagequality_output_acc: 0.5916 - age_output_acc: 0.4440 - weight_output_acc: 0.6597 - bag_output_acc: 0.7222 - footwear_output_acc: 0.6776 - bodypose_output_acc: 0.8851 - emotion_output_acc: 0.7108 - val_loss: 6.1044 - val_gender_output_loss: 0.2643 - val_imagequality_output_loss: 0.9159 - val_age_output_loss: 1.2766 - val_weight_output_loss: 0.9068 - val_bag_output_loss: 0.7382 - val_footwear_output_loss: 0.7788 - val_bodypose_output_loss: 0.3712 - val_emotion_output_loss: 0.8526 - val_gender_output_acc: 0.8983 - val_imagequality_output_acc: 0.5354 - val_age_output_acc: 0.4337 - val_weight_output_acc: 0.6488 - val_bag_output_acc: 0.6999 - val_footwear_output_acc: 0.6596 - val_bodypose_output_acc: 0.8718 - val_emotion_output_acc: 0.7137
# Epoch 12/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7669 - gender_output_loss: 0.1952 - imagequality_output_loss: 0.8496 - age_output_loss: 1.2549 - weight_output_loss: 0.8720 - bag_output_loss: 0.6983 - footwear_output_loss: 0.7310 - bodypose_output_loss: 0.3227 - emotion_output_loss: 0.8432 - gender_output_acc: 0.9256 - imagequality_output_acc: 0.5932 - age_output_acc: 0.4470 - weight_output_acc: 0.6554 - bag_output_acc: 0.7184 - footwear_output_acc: 0.6838 - bodypose_output_acc: 0.8880 - emotion_output_acc: 0.7123 - val_loss: 6.0988 - val_gender_output_loss: 0.2633 - val_imagequality_output_loss: 0.9140 - val_age_output_loss: 1.2754 - val_weight_output_loss: 0.9060 - val_bag_output_loss: 0.7377 - val_footwear_output_loss: 0.7785 - val_bodypose_output_loss: 0.3718 - val_emotion_output_loss: 0.8520 - val_gender_output_acc: 0.9003 - val_imagequality_output_acc: 0.5373 - val_age_output_acc: 0.4361 - val_weight_output_acc: 0.6503 - val_bag_output_acc: 0.6970 - val_footwear_output_acc: 0.6601 - val_bodypose_output_acc: 0.8698 - val_emotion_output_acc: 0.7137
# Epoch 13/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7734 - gender_output_loss: 0.1992 - imagequality_output_loss: 0.8437 - age_output_loss: 1.2599 - weight_output_loss: 0.8761 - bag_output_loss: 0.6982 - footwear_output_loss: 0.7303 - bodypose_output_loss: 0.3233 - emotion_output_loss: 0.8428 - gender_output_acc: 0.9270 - imagequality_output_acc: 0.5945 - age_output_acc: 0.4377 - weight_output_acc: 0.6569 - bag_output_acc: 0.7207 - footwear_output_acc: 0.6819 - bodypose_output_acc: 0.8856 - emotion_output_acc: 0.7108 - val_loss: 6.0963 - val_gender_output_loss: 0.2619 - val_imagequality_output_loss: 0.9140 - val_age_output_loss: 1.2745 - val_weight_output_loss: 0.9055 - val_bag_output_loss: 0.7379 - val_footwear_output_loss: 0.7791 - val_bodypose_output_loss: 0.3717 - val_emotion_output_loss: 0.8517 - val_gender_output_acc: 0.8998 - val_imagequality_output_acc: 0.5339 - val_age_output_acc: 0.4347 - val_weight_output_acc: 0.6498 - val_bag_output_acc: 0.6999 - val_footwear_output_acc: 0.6591 - val_bodypose_output_acc: 0.8703 - val_emotion_output_acc: 0.7132
# Epoch 14/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7571 - gender_output_loss: 0.1976 - imagequality_output_loss: 0.8400 - age_output_loss: 1.2581 - weight_output_loss: 0.8712 - bag_output_loss: 0.6975 - footwear_output_loss: 0.7227 - bodypose_output_loss: 0.3276 - emotion_output_loss: 0.8425 - gender_output_acc: 0.9275 - imagequality_output_acc: 0.6024 - age_output_acc: 0.4428 - weight_output_acc: 0.6561 - bag_output_acc: 0.7193 - footwear_output_acc: 0.6829 - bodypose_output_acc: 0.8848 - emotion_output_acc: 0.7118 - val_loss: 6.0976 - val_gender_output_loss: 0.2635 - val_imagequality_output_loss: 0.9104 - val_age_output_loss: 1.2766 - val_weight_output_loss: 0.9058 - val_bag_output_loss: 0.7378 - val_footwear_output_loss: 0.7784 - val_bodypose_output_loss: 0.3725 - val_emotion_output_loss: 0.8526 - val_gender_output_acc: 0.9003 - val_imagequality_output_acc: 0.5393 - val_age_output_acc: 0.4342 - val_weight_output_acc: 0.6473 - val_bag_output_acc: 0.6960 - val_footwear_output_acc: 0.6596 - val_bodypose_output_acc: 0.8674 - val_emotion_output_acc: 0.7137
# Epoch 15/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7600 - gender_output_loss: 0.1982 - imagequality_output_loss: 0.8461 - age_output_loss: 1.2624 - weight_output_loss: 0.8672 - bag_output_loss: 0.6950 - footwear_output_loss: 0.7237 - bodypose_output_loss: 0.3245 - emotion_output_loss: 0.8428 - gender_output_acc: 0.9251 - imagequality_output_acc: 0.5973 - age_output_acc: 0.4440 - weight_output_acc: 0.6615 - bag_output_acc: 0.7214 - footwear_output_acc: 0.6780 - bodypose_output_acc: 0.8821 - emotion_output_acc: 0.7109 - val_loss: 6.0996 - val_gender_output_loss: 0.2642 - val_imagequality_output_loss: 0.9109 - val_age_output_loss: 1.2765 - val_weight_output_loss: 0.9056 - val_bag_output_loss: 0.7386 - val_footwear_output_loss: 0.7788 - val_bodypose_output_loss: 0.3729 - val_emotion_output_loss: 0.8521 - val_gender_output_acc: 0.8969 - val_imagequality_output_acc: 0.5403 - val_age_output_acc: 0.4312 - val_weight_output_acc: 0.6444 - val_bag_output_acc: 0.6970 - val_footwear_output_acc: 0.6596 - val_bodypose_output_acc: 0.8674 - val_emotion_output_acc: 0.7137
# Epoch 16/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7613 - gender_output_loss: 0.1996 - imagequality_output_loss: 0.8476 - age_output_loss: 1.2607 - weight_output_loss: 0.8658 - bag_output_loss: 0.7009 - footwear_output_loss: 0.7298 - bodypose_output_loss: 0.3199 - emotion_output_loss: 0.8369 - gender_output_acc: 0.9219 - imagequality_output_acc: 0.5926 - age_output_acc: 0.4437 - weight_output_acc: 0.6582 - bag_output_acc: 0.7174 - footwear_output_acc: 0.6801 - bodypose_output_acc: 0.8863 - emotion_output_acc: 0.7125 - val_loss: 6.1033 - val_gender_output_loss: 0.2634 - val_imagequality_output_loss: 0.9174 - val_age_output_loss: 1.2758 - val_weight_output_loss: 0.9055 - val_bag_output_loss: 0.7379 - val_footwear_output_loss: 0.7786 - val_bodypose_output_loss: 0.3721 - val_emotion_output_loss: 0.8525 - val_gender_output_acc: 0.9023 - val_imagequality_output_acc: 0.5373 - val_age_output_acc: 0.4322 - val_weight_output_acc: 0.6454 - val_bag_output_acc: 0.7014 - val_footwear_output_acc: 0.6601 - val_bodypose_output_acc: 0.8679 - val_emotion_output_acc: 0.7146
# Epoch 17/20
# 91/91 [==============================] - 116s 1s/step - loss: 5.7344 - gender_output_loss: 0.1947 - imagequality_output_loss: 0.8376 - age_output_loss: 1.2569 - weight_output_loss: 0.8637 - bag_output_loss: 0.6937 - footwear_output_loss: 0.7253 - bodypose_output_loss: 0.3240 - emotion_output_loss: 0.8386 - gender_output_acc: 0.9246 - imagequality_output_acc: 0.6020 - age_output_acc: 0.4420 - weight_output_acc: 0.6564 - bag_output_acc: 0.7219 - footwear_output_acc: 0.6762 - bodypose_output_acc: 0.8844 - emotion_output_acc: 0.7135 - val_loss: 6.1002 - val_gender_output_loss: 0.2623 - val_imagequality_output_loss: 0.9175 - val_age_output_loss: 1.2743 - val_weight_output_loss: 0.9056 - val_bag_output_loss: 0.7375 - val_footwear_output_loss: 0.7788 - val_bodypose_output_loss: 0.3721 - val_emotion_output_loss: 0.8519 - val_gender_output_acc: 0.9008 - val_imagequality_output_acc: 0.5359 - val_age_output_acc: 0.4352 - val_weight_output_acc: 0.6478 - val_bag_output_acc: 0.6979 - val_footwear_output_acc: 0.6572 - val_bodypose_output_acc: 0.8659 - val_emotion_output_acc: 0.7137
# Epoch 18/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7668 - gender_output_loss: 0.1956 - imagequality_output_loss: 0.8430 - age_output_loss: 1.2560 - weight_output_loss: 0.8637 - bag_output_loss: 0.6968 - footwear_output_loss: 0.7320 - bodypose_output_loss: 0.3322 - emotion_output_loss: 0.8476 - gender_output_acc: 0.9243 - imagequality_output_acc: 0.5957 - age_output_acc: 0.4364 - weight_output_acc: 0.6590 - bag_output_acc: 0.7254 - footwear_output_acc: 0.6800 - bodypose_output_acc: 0.8817 - emotion_output_acc: 0.7101 - val_loss: 6.1012 - val_gender_output_loss: 0.2626 - val_imagequality_output_loss: 0.9169 - val_age_output_loss: 1.2745 - val_weight_output_loss: 0.9059 - val_bag_output_loss: 0.7374 - val_footwear_output_loss: 0.7790 - val_bodypose_output_loss: 0.3725 - val_emotion_output_loss: 0.8523 - val_gender_output_acc: 0.9013 - val_imagequality_output_acc: 0.5339 - val_age_output_acc: 0.4347 - val_weight_output_acc: 0.6444 - val_bag_output_acc: 0.7004 - val_footwear_output_acc: 0.6596 - val_bodypose_output_acc: 0.8669 - val_emotion_output_acc: 0.7132
# Epoch 19/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7351 - gender_output_loss: 0.2017 - imagequality_output_loss: 0.8429 - age_output_loss: 1.2562 - weight_output_loss: 0.8666 - bag_output_loss: 0.6938 - footwear_output_loss: 0.7308 - bodypose_output_loss: 0.3102 - emotion_output_loss: 0.8331 - gender_output_acc: 0.9244 - imagequality_output_acc: 0.5939 - age_output_acc: 0.4440 - weight_output_acc: 0.6616 - bag_output_acc: 0.7228 - footwear_output_acc: 0.6832 - bodypose_output_acc: 0.8915 - emotion_output_acc: 0.7122 - val_loss: 6.1087 - val_gender_output_loss: 0.2639 - val_imagequality_output_loss: 0.9231 - val_age_output_loss: 1.2728 - val_weight_output_loss: 0.9054 - val_bag_output_loss: 0.7386 - val_footwear_output_loss: 0.7801 - val_bodypose_output_loss: 0.3726 - val_emotion_output_loss: 0.8522 - val_gender_output_acc: 0.8998 - val_imagequality_output_acc: 0.5324 - val_age_output_acc: 0.4352 - val_weight_output_acc: 0.6464 - val_bag_output_acc: 0.6979 - val_footwear_output_acc: 0.6586 - val_bodypose_output_acc: 0.8654 - val_emotion_output_acc: 0.7132
# Epoch 20/20
# 91/91 [==============================] - 117s 1s/step - loss: 5.7252 - gender_output_loss: 0.1947 - imagequality_output_loss: 0.8369 - age_output_loss: 1.2573 - weight_output_loss: 0.8602 - bag_output_loss: 0.6942 - footwear_output_loss: 0.7225 - bodypose_output_loss: 0.3209 - emotion_output_loss: 0.8386 - gender_output_acc: 0.9230 - imagequality_output_acc: 0.5968 - age_output_acc: 0.4404 - weight_output_acc: 0.6558 - bag_output_acc: 0.7214 - footwear_output_acc: 0.6818 - bodypose_output_acc: 0.8831 - emotion_output_acc: 0.7133 - val_loss: 6.1025 - val_gender_output_loss: 0.2661 - val_imagequality_output_loss: 0.9134 - val_age_output_loss: 1.2739 - val_weight_output_loss: 0.9057 - val_bag_output_loss: 0.7375 - val_footwear_output_loss: 0.7807 - val_bodypose_output_loss: 0.3728 - val_emotion_output_loss: 0.8524 - val_gender_output_acc: 0.9003 - val_imagequality_output_acc: 0.5388 - val_age_output_acc: 0.4312 - val_weight_output_acc: 0.6488 - val_bag_output_acc: 0.6989 - val_footwear_output_acc: 0.6596 - val_bodypose_output_acc: 0.8659 - val_emotion_output_acc: 0.7137

# %%
import matplotlib.pyplot as plt

def plot_pairs(metric, val_metric):
  plt.plot(range(len(metric)), metric, color='blue')
  plt.plot(range(len(val_metric)), val_metric, color='green')
  plt.show()

def get_all_values(metric):
  return history.history[metric] + history2.history[metric] + history3.history[metric]

plot_pairs(get_all_values('loss'), get_all_values('val_loss'))
for cat in ['gender', 'imagequality', 'age', 'weight', 'bag', 'footwear', 'bodypose', 'emotion']:
  print(cat, ' loss')
  plot_pairs(get_all_values(f'{cat}_output_loss'), get_all_values(f'val_{cat}_output_loss'))
  print(cat, ' acc')
  plot_pairs(get_all_values(f'{cat}_output_acc'), get_all_values(f'val_{cat}_output_acc'))
# Out:
# gender  loss
# gender  acc
# imagequality  loss
# imagequality  acc
# age  loss
# age  acc
# weight  loss
# weight  acc
# bag  loss
# bag  acc
# footwear  loss
# footwear  acc
# bodypose  loss
# bodypose  acc
# emotion  loss
# emotion  acc
